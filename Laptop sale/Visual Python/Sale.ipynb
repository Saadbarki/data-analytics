# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
file_path = '/mnt/data/laptop prices.xlsx'

# %%
df = pd.read_excel("C:/Users/saadk/Downloads/DataSet/Laptop sale/laptop prices.xlsx")

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
average_price = df['Price_euros'].mean()
print("Average Price of Laptops:", average_price)
# Out:
# Average Price of Laptops: 1134.9690588235292

# %%
most_common_brand = df['Company'].mode()[0]  # Replace 'Brand' with the actual column name if different
print("Most Common Brand:", most_common_brand)
# Out:
# Most Common Brand: Dell

# %%
category_counts = df['TypeName'].value_counts()  # Replace 'Category' with the actual column name if different
print("Laptops by TypeName:\n", category_counts)
# Out:
# Laptops by TypeName:
#  TypeName
# Notebook              707
# Gaming                205
# Ultrabook             194
# 2 in 1 Convertible    117
# Workstation            29
# Netbook                23
# Name: count, dtype: int64

# %%
# Plot a bar chart for the number of laptops by brand
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')  # Replace 'category_counts' with the actual variable name
plt.title("Number of Laptops by Brand")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Price_euros'], bins=20, color='lightgreen', edgecolor='black')  # Use 'Price_euros' instead of 'Price'
plt.title("Distribution of Laptop Prices")
plt.xlabel("Price (Euros)")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the average price per brand and plot
avg_price_brand = df.groupby('Company')['Price_euros'].mean()  # Use 'Company' and 'Price_euros'
avg_price_brand.plot(kind='bar', color='salmon', figsize=(10, 6))
plt.title("Average Price by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Price (Euros)")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Company', y='Price_euros', palette='Set2')
plt.title('Price Distribution by Brand')
plt.xlabel('Brand')
plt.ylabel('Price (Euros)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\saadk\AppData\Local\Temp\ipykernel_4468\1462408168.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Company', y='Price_euros', palette='Set2')

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='Company', y='Price_euros', palette='muted')
plt.title('Price Distribution by Brand (Violin Plot)')
plt.xlabel('Brand')
plt.ylabel('Price (Euros)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\saadk\AppData\Local\Temp\ipykernel_4468\81990427.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Company', y='Price_euros', palette='muted')

# %%
sns.pairplot(df[['Price_euros', 'Ram', 'Weight']], diag_kind='kde')
plt.suptitle('Pairwise Relationships in the Laptop Dataset', y=1.02)
plt.show()
